# %%
import os
os.getcwd()
# Out:
# '/Users/onurmohamedhaniffa/Diabetes-Prediction-Algorithms-/Notebooks'

# %%
import sys, os
sys.path.append("..")   

from SRC.preprocessing import load_data, impute_missing_values, remove_outliers

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("../Data/pima.csv")

df_clean = impute_missing_values(df.copy())
df_clean = remove_outliers(df_clean.copy())

plt.figure(figsize=(10, 6))
sns.heatmap(df_clean.corr(), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap (After Preprocessing)")
plt.show()
# Out:
# Zero counts per column:
#  Pregnancies                 111
# Glucose                       5
# BloodPressure                35
# SkinThickness               227
# Insulin                     374
# BMI                          11
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                     500
# dtype: int64
# Missing values after imputation:
#  Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64
# Extreme outliers in Insulin: 60
# Extreme outliers in SkinThickness: 6
# Total unique rows to remove: 65
# Shape after outlier removal: (703, 9)
